# %% [markdown]
# # 모델선택(Model Selection)
#
# - [StatQuest: Cross-Validation](https://youtu.be/fSytzGwwBVw)
#     - 교차검증 사용 이유는 무엇일까요? (두 가지를 찾아 보세요)

# %% [markdown]
# #### 이번 노트는 Ames Housing dataset 을 이용해서 진행해 보겠습니다.

# %%
import pandas as pd
# Import house prices data
train = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/house-prices/house_prices_train.csv')

# %% [markdown]
# ##### 훈련 데이터에서 마지막에 사용할 테스트세트를 따로 구분해 놓겠습니다.

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(train, test_size=260, random_state=2)

# %%
train.shape, test.shape
# Out:
# ((1200, 81), (260, 81))

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(train, minimal=True).to_notebook_iframe()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
import pandas as pd

# %%
# 훈련/테스트 세트 모두 전처리 하기위한 함수입니다.
def clean(df):
    df = df.copy()
    
    ## 타겟변수의 이상치(outlier)를 제거합니다.
    df['SalePrice'] = df[df['SalePrice'] < np.percentile(df['SalePrice'], 99)]['SalePrice']
    
    ## 타겟변수가 결측치인 샘플을 제거 합니다.
    df.dropna(subset=['SalePrice'], inplace=True)

    ## id 변수를 제거합니다.
    df = df.drop("Id", axis = 1)

    ## 변수를 합치고 새로운 변수를 생성합니다.(참고, https://www.kaggle.com/yadavsarthak/house-prices-advanced-regression-techniques/you-got-this-feature-engineering-and-lasso)
    df['All_Flr_SF'] = df['1stFlrSF'] + df['2ndFlrSF']
    df['All_Liv_SF'] = df['All_Flr_SF'] + df['LowQualFinSF'] + df['GrLivArea']
    df = df.drop(['1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea'], axis=1)

    ## 변수의 이상치를 제거합니다.
    df['All_Flr_SF'] = df[df['All_Flr_SF'] < np.percentile(df['All_Flr_SF'], 99.5)]['All_Flr_SF']
    df['All_Liv_SF'] = df[df['All_Liv_SF'] < np.percentile(df['All_Liv_SF'], 99.5)]['All_Liv_SF']
    
    ## 결측값을 파이프라인에서 평균/중간값으로 처리하면 안되는 몇몇 특성이 있어 미리 처리하겠습니다.
    ## (https://www.kaggle.com/juliensiems/cleaning-new-features-gps-coordinates-included)
    
    ## 이외 특성들의 결측값은 파이프라인에서 처리합니다.
    
    # Alley : NA == "no alley access"
    df.loc[:, "Alley"] = df.loc[:, "Alley"].fillna("None")
    
    # BedroomAbvGr : NA ~ 0
    df.loc[:, "BedroomAbvGr"] = df.loc[:, "BedroomAbvGr"].fillna(0)
    
    # BsmtQual etc : NA == "no basement"
    df.loc[:, "BsmtQual"] = df.loc[:, "BsmtQual"].fillna("No")
    df.loc[:, "BsmtCond"] = df.loc[:, "BsmtCond"].fillna("No")
    df.loc[:, "BsmtExposure"] = df.loc[:, "BsmtExposure"].fillna("No")
    df.loc[:, "BsmtFinType1"] = df.loc[:, "BsmtFinType1"].fillna("No")
    df.loc[:, "BsmtFinType2"] = df.loc[:, "BsmtFinType2"].fillna("No")
    df.loc[:, "BsmtFullBath"] = df.loc[:, "BsmtFullBath"].fillna(0)
    df.loc[:, "BsmtHalfBath"] = df.loc[:, "BsmtHalfBath"].fillna(0)
    df.loc[:, "BsmtUnfSF"] = df.loc[:, "BsmtUnfSF"].fillna(0)
    
    # CentralAir : NA ~ No
    df.loc[:, "CentralAir"] = df.loc[:, "CentralAir"].fillna("N")
    
    # Condition : NA ~ Normal
    df.loc[:, "Condition1"] = df.loc[:, "Condition1"].fillna("Norm")
    df.loc[:, "Condition2"] = df.loc[:, "Condition2"].fillna("Norm")
    
    # EnclosedPorch : NA ~ no enclosed porch
    df.loc[:, "EnclosedPorch"] = df.loc[:, "EnclosedPorch"].fillna(0)
    
    # External stuff : NA ~ average
    df.loc[:, "ExterCond"] = df.loc[:, "ExterCond"].fillna("TA")
    df.loc[:, "ExterQual"] = df.loc[:, "ExterQual"].fillna("TA")
    
    # Fence : NA == "no fence"
    df.loc[:, "Fence"] = df.loc[:, "Fence"].fillna("No")
    
    # FireplaceQu : NA == "no fireplace"
    df.loc[:, "FireplaceQu"] = df.loc[:, "FireplaceQu"].fillna("No")
    df.loc[:, "Fireplaces"] = df.loc[:, "Fireplaces"].fillna(0)
    
    # Functional : NA == "typical"
    df.loc[:, "Functional"] = df.loc[:, "Functional"].fillna("Typ")
    
    # GarageType etc : NA == "no garage"
    df.loc[:, "GarageType"] = df.loc[:, "GarageType"].fillna("No")
    df.loc[:, "GarageFinish"] = df.loc[:, "GarageFinish"].fillna("No")
    df.loc[:, "GarageQual"] = df.loc[:, "GarageQual"].fillna("No")
    df.loc[:, "GarageCond"] = df.loc[:, "GarageCond"].fillna("No")
    df.loc[:, "GarageArea"] = df.loc[:, "GarageArea"].fillna(0)
    df.loc[:, "GarageCars"] = df.loc[:, "GarageCars"].fillna(0)
    
    # HalfBath : NA ~ no half baths above grade
    df.loc[:, "HalfBath"] = df.loc[:, "HalfBath"].fillna(0)
    
    # HeatingQC : NA ~ typical
    df.loc[:, "HeatingQC"] = df.loc[:, "HeatingQC"].fillna("TA")
    
    # KitchenAbvGr : NA ~ 0
    df.loc[:, "KitchenAbvGr"] = df.loc[:, "KitchenAbvGr"].fillna(0)
    
    # KitchenQual : NA ~ typical
    df.loc[:, "KitchenQual"] = df.loc[:, "KitchenQual"].fillna("TA")
    
    # LotFrontage : NA ~ no lot frontage
    df.loc[:, "LotFrontage"] = df.loc[:, "LotFrontage"].fillna(0)
    
    # LotShape : NA ~ regular
    df.loc[:, "LotShape"] = df.loc[:, "LotShape"].fillna("Reg")
    
    # MasVnrType : NA ~ no veneer
    df.loc[:, "MasVnrType"] = df.loc[:, "MasVnrType"].fillna("None")
    df.loc[:, "MasVnrArea"] = df.loc[:, "MasVnrArea"].fillna(0)
    
    # MiscFeature : NA == "no misc feature"
    df.loc[:, "MiscFeature"] = df.loc[:, "MiscFeature"].fillna("No")
    df.loc[:, "MiscVal"] = df.loc[:, "MiscVal"].fillna(0)
    
    # OpenPorchSF : NA ~ no open porch
    df.loc[:, "OpenPorchSF"] = df.loc[:, "OpenPorchSF"].fillna(0)
    
    # PavedDrive : NA ~ not paved
    df.loc[:, "PavedDrive"] = df.loc[:, "PavedDrive"].fillna("N")
    
    # PoolQC : NA == "no pool"
    df.loc[:, "PoolQC"] = df.loc[:, "PoolQC"].fillna("No")
    df.loc[:, "PoolArea"] = df.loc[:, "PoolArea"].fillna(0)
    
    # SaleCondition : NA ~ normal sale
    df.loc[:, "SaleCondition"] = df.loc[:, "SaleCondition"].fillna("Normal")
    
    # ScreenPorch : NA ~ no screen porch
    df.loc[:, "ScreenPorch"] = df.loc[:, "ScreenPorch"].fillna(0)
    
    # TotRmsAbvGrd : NA ~ 0
    df.loc[:, "TotRmsAbvGrd"] = df.loc[:, "TotRmsAbvGrd"].fillna(0)
    
    # Utilities : NA ~ all public utilities
    df.loc[:, "Utilities"] = df.loc[:, "Utilities"].fillna("AllPub")
    
    # WoodDeckSF : NA ~ no wood deck
    df.loc[:, "WoodDeckSF"] = df.loc[:, "WoodDeckSF"].fillna(0)
    df[df['Neighborhood'] == 'Greens']
    

    return df

# %%
train = clean(train)
test = clean(test)

# %%
train.shape, test.shape
# Out:
# ((1188, 78), (257, 78))

# %% [markdown]
# ## 교차검증(Cross-validation)

# %% [markdown]
# 지금까지는 데이터를 **훈련/검증/테스트 세트**로 나누어 학습을 진행해 왔습니다.(이 방법은 **hold-out 교차검증** 이라고 합니다.) 이 방법은 어떤 문제점을 가지고 있을까요?
#
# - 학습에 사용가능한 데이터가 충분하다면 문제가 없겠지만, 훈련세트의 크기가 모델학습에 충분하지 않을 경우 문제가 될 수 있습니다.
# - 검증세트 크기가 충분히 크지 않다면 예측 성능에 대한 추정이 부정확할 것입니다.
#
# 이것 외에 다른 문제점도 있습니다. 여러분은 앞으로 수많은 기계학습 알고리즘을 사용할 것인데 모든 문제에 적용가능한 최고의 학습 모델은 없다는 것을 알고 계시지요?
#
# - **우리 문제를 풀기위해 어떤 학습 모델을 사용해야 할 것인지?**
# - **어떤 하이퍼파라미터를 사용할 것인지?**
#
# 이러한 문제가 **모델선택(Model selection)** 문제입니다.
#
# 이렇게 데이터의 크기에 대한 문제, 모델선택에 대한 문제를 해결하기 위해 사용하는 방법 중 한 가지가 **교차검증**입니다.
#
# ##### 참고:교차검증은 **시계열(time series)** 데이터에는 적합하지 않습니다
#
#
# <img src="https://sebastianraschka.com/images/blog/2016/model-evaluation-selection-part3/kfold.png" width="700">

# %% [markdown]
# ### 교차검증을 사용해 보겠습니다.

# %% [markdown]
# 교차검증을 하기 위해서는 데이터를 k개로 등분하여야 하는데 이를 k-fold cross-validation(CV) 라고 합니다. k개의 집합에서 k-1 개의 부분집합을 훈련에 사용하고 나머지 부분집합을 테스트 데이터로 검증하게 됩니다.
#
# 예를들어, 데이터를 3등분으로 나누고 검증(1/3)과 훈련세트(2/3)를 총 세번 바꾸어가며 검증하는 것은 3-fold CV 입니다.
#
# 10-fold CV의 경우 검증을 총 10번을 하겠지요!
#
#
# 사이킷런에 [cross_val_score](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html#sklearn-model-selection-cross-val-score) 를 사용하면 교차검증을 쉽게 적용할 수 있습니다.
#
#
# cross_val_score 는 어떻게 사용할까요?
#
# - [3.1.1. Computing cross-validated metrics
# ](https://scikit-learn.org/stable/modules/cross_validation.html#computing-cross-validated-metrics)
#
# 학습된 모델, 학습데이터, 타겟데이터, k 값(default = 5)을 준비하면 쉽게 사용할 수 있습니다.

# %% [markdown]
# #### 선형모델을 만들어 교차검증을 수행해 보겠습니다.

# %%
# !pip install category_encoders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting category_encoders
#   Downloading category_encoders-2.6.0-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 KB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.9/dist-packages (from category_encoders) (1.4.4)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from category_encoders) (1.22.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from category_encoders) (1.10.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from category_encoders) (0.13.5)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.9/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.9/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.5->category_encoders) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.9.0->category_encoders) (23.0)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.0

# %%
from category_encoders import OneHotEncoder
from sklearn.feature_selection import f_regression, SelectKBest
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# (참고) warning 제거를 위한 코드
np.seterr(divide='ignore', invalid='ignore')

target = 'SalePrice'
features = train.columns.drop([target])
X_train = train[features]
y_train = train[target]

X_test = test[features]
y_test = test[target]


pipe = make_pipeline(
    OneHotEncoder(use_cat_names=True), 
    SimpleImputer(strategy='mean'), 
    StandardScaler(), 
    SelectKBest(f_regression, k=20),
    Ridge(alpha=1.0)
)

# 3-fold 교차검증을 수행합니다.
k = 3
scores = cross_val_score(pipe, X_train, y_train, cv=k, 
                         scoring='neg_mean_absolute_error')

print(f'MAE ({k} folds):', -scores)
# Out:
# MAE (3 folds): [19912.3716215  23214.74205495 18656.29713167]

# %%
-scores.mean()
# Out:
# 20594.470269371846

# %%
scores.std()
# Out:
# 1922.4635156881661

# %% [markdown]
# ### 랜덤포레스트에 적용해 보겠습니다.

# %%
from category_encoders import TargetEncoder
from sklearn.ensemble import RandomForestRegressor

pipe = make_pipeline(
    # TargetEncoder: 범주형 변수 인코더로, 타겟값을 특성의 범주별로 평균내어 그 값으로 인코딩
    TargetEncoder(min_samples_leaf=1, smoothing=1), 
    SimpleImputer(strategy='median'), 
    RandomForestRegressor(max_depth = 10, n_jobs=-1, random_state=2)
)

k = 3

scores = cross_val_score(pipe, X_train, y_train, cv=k, 
                         scoring='neg_mean_absolute_error')

print(f'MAE for {k} folds:', -scores)
# Out:
# MAE for 3 folds: [16284.56815293 19518.4543002  15279.0092975 ]

# %%
-scores.mean()
# Out:
# 17027.34391687409

# %%
scores.std()
# Out:
# 1808.6846711266562

# %% [markdown]
# #### (참고) TargetEncoder 인코딩을 확인해 보겠습니다.

# %%
X_train.describe(exclude='number')
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1188   1188  1188     1188        1188      1188      1188
# unique        5      2     3        4           4         2         5
# top          RL   Pave  None      Reg         Lvl    AllPub    Inside
# freq        936   1184  1112      759        1068      1187       856
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1188         1188       1188  ...       1188         1188
# unique         3           25          9  ...          7            4
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1122          183       1024  ...        709          508
#
#        GarageQual GarageCond PavedDrive PoolQC Fence MiscFeature SaleType  \
# count        1188       1188       1188   1188  1188        1188     1188
# unique          6          6          3      3     5           5        9
# top            TA         TA          Y     No    No          No       WD
# freq         1068       1080       1084   1184   961        1140     1036
#
#        SaleCondition
# count           1188
# unique             6
# top           Normal
# freq             986
#
# [4 rows x 43 columns]

# %%
enc = TargetEncoder(min_samples_leaf=1, smoothing=1000) 
enc.fit_transform(X_train,y_train)['LotShape'].value_counts()
# Out:
# 166368.017847    759
# 190133.621187    391
# 194093.059489     28
# 196089.739213     10
# Name: LotShape, dtype: int64

# %%
X_train['LotShape'].value_counts()
# Out:
# Reg    759
# IR1    391
# IR2     28
# IR3     10
# Name: LotShape, dtype: int64

# %%
y_train[X_train[X_train.LotShape == 'Reg'].index].sum() / 759
# Out:
# 161871.9486166008

# %% [markdown]
# #### 랜덤포레스트 학습시 `max_depth`를 10으로 주었습니다.
# 그리고 다른 하이퍼파라미터는 기본값으로 사용하였는데요.
#
# 이 값이 적정할까요?
# 어떻게 하이퍼파라미터를 조절할 수 있을까요?

# %% [markdown]
# ## 하이퍼파라미터 튜닝

# %% [markdown]
# #### 사이킷런을 사용하여 하이퍼파라미터를 최적화 할 수 있습니다

# %% [markdown]
# 머신러닝 모델을 만들때 중요한 이슈는 최적화(optimization)와 일반화(generalization) 입니다.
#
# - **최적화**는 훈련 데이터로 더 좋은 성능을 얻기 위해 모델을 조정하는 과정이며,
# - **일반화**는 학습된 모델이 처음 본 데이터에서 얼마나 좋은 성능을 내는지를 이야기 합니다.
#
# 모델의 복잡도를 높이는 과정에서 훈련/검증 세트의 손실이 함께 감소하는 시점은 과소적합(underfitting) 되었다고 합니다.
#
# 이 때는 모델이 더 학습 될 여지가 있습니다. 하지만 어느 시점부터 훈련데이터의 손실은 계속 감소하는데 검증데이터의 손실은 증가하는 때가 있습니다. 이때 우리는 과적합(overfitting) 되었다고 합니다.
#
# 이상적인 모델은 과소적합과 과적합 사이에 존재합니다.
#
# <img src="https://www.researchgate.net/profile/Hayder_Al-Behadili/publication/325999203/figure/fig4/AS:641844216074241@1530038994324/Overfitting-and-underfitting-effect-on-error.png" width="600" />

# %% [markdown]
# ### 검증곡선(validation curve)를 그려 봅시다.
# **검증곡선**은 훈련/검증데이터에 대해
#     - y축: 스코어
#     - x축: 하이퍼파라미터
# 로 그린 그래프 입니다.
#
# (참고로 **훈련곡선**(learning curve)이라는 용어는 x축이 훈련데이터 수(# of training samples)에 대해 그린 것 으로 검증곡선과 혼동하지 마세요.)
#
# 그럼 이제 검증곡선을 그려보고 학습이 최적화된 지점을 찾아 봅시다.
#
# Scikit-learn, [validation curves](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.validation_curve.html#sklearn-model-selection-validation-curve)
# 를 사용하면 다양한 하이퍼파라미터 값에 대해 훈련/검증 스코어 값의 변화를 확인할 수 있습니다. 이것은 다음에 배울 grid search에서 한 가지 파라미터를 사용하는 것과 유사합니다.

# %% [markdown]
# 사실 하나의 파라미터만 가지고 검증곡선을 그리는 것이 현실적으로 아주 유용하지는 않습니다. 현실에서는 더 많은 파라미터의 변화에 대한 결과를 보는 것이 중요하지요.
#
# 한 번 결정트리에서 과적합을 막아줄 때 제한하는 `max_depth`를 변화시키며 검증곡선을 그려봅시다.

# %%
import matplotlib.pyplot as plt
from category_encoders import OrdinalEncoder
from sklearn.model_selection import validation_curve
from sklearn.tree import DecisionTreeRegressor

pipe = make_pipeline(
    OrdinalEncoder(), 
    SimpleImputer(), 
    DecisionTreeRegressor()
)

depth = range(1, 30, 2)
ts, vs = validation_curve(
    pipe, X_train, y_train
    , param_name='decisiontreeregressor__max_depth'
    , param_range=depth, scoring='neg_mean_absolute_error'
    , cv=3
    , n_jobs=-1
)

train_scores_mean = np.mean(-ts, axis=1)
validation_scores_mean = np.mean(-vs, axis=1)

fig, ax = plt.subplots()

# 훈련세트 검증곡선
ax.plot(depth, train_scores_mean, label='training error')

# 검증세트 검증곡선
ax.plot(depth, validation_scores_mean, label='validation error')

# 이상적인 max_depth
ax.vlines(5,0, train_scores_mean.max(), color='blue')

# 그래프 셋팅
ax.set(title='Validation Curve'
      , xlabel='Model Complexity(max_depth)', ylabel='MAE')
ax.legend()
fig.dpi = 100

# %% [markdown]
# 이대로 트리의 깊이를 정해야 한다면 max_depth = 5 부근에서 설정해 주어야 과적합을 막고 일반화 성능을 지킬 것 같습니다

# %% [markdown]
# ### Randomized Search CV
#
# 이제 여러 하이퍼파라미터의 최적값을 찾기 위해 **[RandomizedSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)** 를 사용해 봅시다.

# %% [markdown]
# 하이퍼파라미터는 모델 훈련중에 학습이 되지 않는 파라미터입니다. 그래서 사용자가 직접 정해주어야 합니다.
#
# 현실적으로 하이퍼파라미터를 수작업으로 정해주는 것은 어렵습니다. 최적의 하이퍼파라미터 조합을 찾아주는 도구를 사용해야 합니다.
# 사이킷런에 하이퍼파라미터 튜닝을 도와주는 좋은 툴이 두 가지 있습니다.
#
# - [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html#sklearn.model_selection.GridSearchCV): 검증하고 싶은 하이퍼파라미터들의 수치를 정해주고 그 조합을 모두 검증합니다.
#
# - [RandomizedSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html): 검증하려는 하이퍼파라미터들의 값 범위를 지정해주면 무작위로 값을 지정해 그 조합을 모두 검증합니다.
#
# <img src="https://www.researchgate.net/profile/Amirhessam_Tahmassebi/publication/333073682/figure/fig4/AS:759165278490624@1558010515055/An-illustration-of-grid-search-and-random-search-layouts.ppm" width="600" />

# %% [markdown]
# ### Ridge 회귀모델의 하이퍼파라미터를 튜닝해보겠습니다.

# %%
from sklearn.model_selection import RandomizedSearchCV

pipe = make_pipeline(
    OneHotEncoder(use_cat_names=True)
    , SimpleImputer()
    , StandardScaler()
    , SelectKBest(f_regression)
    , Ridge()
)

# 튜닝할 하이퍼파라미터의 범위를 지정해 주는 부분
dists = {
    'simpleimputer__strategy': ['mean', 'median'], 
    'selectkbest__k': range(1, len(X_train.columns)+1), 
    'ridge__alpha': [0.1, 1, 10], 
}

clf = RandomizedSearchCV(
    pipe, 
    param_distributions=dists, 
    n_iter=50, 
    cv=3,
    scoring='neg_mean_absolute_error',
    verbose=1,
    n_jobs=-1
)

clf.fit(X_train, y_train);
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits

# %%
print('최적 하이퍼파라미터: ', clf.best_params_)
print('MAE: ', -clf.best_score_)
# Out:
# 최적 하이퍼파라미터:  {'simpleimputer__strategy': 'mean', 'selectkbest__k': 57, 'ridge__alpha': 10}
# MAE:  18490.96818696366

# %% [markdown]
# RandomSearchCV는 n_iter(=50) * 3 교차검증 = 150 tasks를 수행했습니다
#
# 하지만 GridSearchCV를 사용해 이 범위를 검색하려면 얼마나 많은 태스크가 필요할까요?
# -  2 imputation * n cols * 3 alphas * 3 cv

# %%
2 * len(X_train.columns) * 3 * 3
# Out:
# 1386

# %% [markdown]
# #### 각 하이퍼파라미터 조합으로 만들어진 모델들을 순위별로 나열해 봅니다.

# %%
# rank_test_score: 테스트 순위
# mean_score_time: 예측에 걸리는 시간
pd.DataFrame(clf.cv_results_).sort_values(by='rank_test_score').T
# Out:
#                                                                               9   \
# mean_fit_time                                                           0.532178
# std_fit_time                                                            0.017523
# mean_score_time                                                         0.186477
# std_score_time                                                          0.069434
# param_simpleimputer__strategy                                               mean
# param_selectkbest__k                                                          57
# param_ridge__alpha                                                            10
# params                         {'simpleimputer__strategy': 'mean', 'selectkbe...
# split0_test_score                                                  -18772.940787
# split1_test_score                                                  -19763.764924
# split2_test_score                                                   -16936.19885
# mean_test_score                                                    -18490.968187
# std_test_score                                                       1171.441814
# rank_test_score                                                                1
#
#                                                                               33  \
# mean_fit_time                                                           0.889543
# std_fit_time                                                            0.131818
# mean_score_time                                                         0.229815
# std_score_time                                                          0.025596
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                          61
# param_ridge__alpha                                                            10
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                   -18827.44278
# split1_test_score                                                  -19758.478209
# split2_test_score                                                  -16932.158917
# mean_test_score                                                    -18506.026636
# std_test_score                                                       1176.010612
# rank_test_score                                                                2
#
#                                                                               43  \
# mean_fit_time                                                           0.503601
# std_fit_time                                                            0.008143
# mean_score_time                                                         0.160435
# std_score_time                                                          0.017406
# param_simpleimputer__strategy                                               mean
# param_selectkbest__k                                                          64
# param_ridge__alpha                                                            10
# params                         {'simpleimputer__strategy': 'mean', 'selectkbe...
# split0_test_score                                                  -18602.711537
# split1_test_score                                                  -20181.849909
# split2_test_score                                                  -16941.564707
# mean_test_score                                                    -18575.375384
# std_test_score                                                        1322.98211
# rank_test_score                                                                3
#
#                                                                               31  \
# mean_fit_time                                                           0.519894
# std_fit_time                                                            0.008009
# mean_score_time                                                         0.133904
# std_score_time                                                          0.004606
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                          64
# param_ridge__alpha                                                            10
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                  -18609.902862
# split1_test_score                                                  -20182.150694
# split2_test_score                                                  -16941.663042
# mean_test_score                                                    -18577.905533
# std_test_score                                                       1323.117009
# rank_test_score                                                                4
#
#                                                                               17  \
# mean_fit_time                                                           0.527752
# std_fit_time                                                            0.021507
# mean_score_time                                                         0.132135
# std_score_time                                                          0.004138
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                          55
# param_ridge__alpha                                                           0.1
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                  -18823.038347
# split1_test_score                                                  -19939.470739
# split2_test_score                                                  -17112.224222
# mean_test_score                                                    -18624.911103
# std_test_score                                                       1162.689847
# rank_test_score                                                                5
#
#                                                                               21  \
# mean_fit_time                                                           0.817443
# std_fit_time                                                            0.195826
# mean_score_time                                                         0.213114
# std_score_time                                                          0.024449
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                          60
# param_ridge__alpha                                                             1
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                  -18818.205752
# split1_test_score                                                  -20004.046352
# split2_test_score                                                   -17210.10922
# mean_test_score                                                    -18677.453775
# std_test_score                                                       1144.954006
# rank_test_score                                                                6
#
#                                                                               45  \
# mean_fit_time                                                           0.662666
# std_fit_time                                                            0.175096
# mean_score_time                                                         0.162603
# std_score_time                                                          0.044173
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                          61
# param_ridge__alpha                                                             1
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                  -18872.472515
# split1_test_score                                                  -19924.504418
# split2_test_score                                                  -17244.065404
# mean_test_score                                                    -18680.347446
# std_test_score                                                       1102.685316
# rank_test_score                                                                7
#
#                                                                               8   \
# mean_fit_time                                                           0.521102
# std_fit_time                                                            0.003028
# mean_score_time                                                          0.13382
# std_score_time                                                          0.005388
# param_simpleimputer__strategy                                               mean
# param_selectkbest__k                                                          56
# param_ridge__alpha                                                           0.1
# params                         {'simpleimputer__strategy': 'mean', 'selectkbe...
# split0_test_score                                                  -18813.751293
# split1_test_score                                                  -19937.574505
# split2_test_score                                                  -17367.119926
# mean_test_score                                                    -18706.148575
# std_test_score                                                        1052.13844
# rank_test_score                                                                8
#
#                                                                               28  \
# mean_fit_time                                                            0.54015
# std_fit_time                                                            0.010332
# mean_score_time                                                         0.129286
# std_score_time                                                           0.00209
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                          77
# param_ridge__alpha                                                             1
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                  -17990.245813
# split1_test_score                                                  -20154.496816
# split2_test_score                                                  -17985.137829
# mean_test_score                                                    -18709.960152
# std_test_score                                                       1021.443799
# rank_test_score                                                                9
#
#                                                                               19  \
# mean_fit_time                                                           0.512796
# std_fit_time                                                            0.014365
# mean_score_time                                                         0.133804
# std_score_time                                                          0.011071
# param_simpleimputer__strategy                                               mean
# param_selectkbest__k                                                          63
# param_ridge__alpha                                                             1
# params                         {'simpleimputer__strategy': 'mean', 'selectkbe...
# split0_test_score                                                  -18552.133061
# split1_test_score                                                  -20377.091997
# split2_test_score                                                  -17242.339933
# mean_test_score                                                    -18723.854997
# std_test_score                                                       1285.504815
# rank_test_score                                                               10
#
#                                ...  \
# mean_fit_time                  ...
# std_fit_time                   ...
# mean_score_time                ...
# std_score_time                 ...
# param_simpleimputer__strategy  ...
# param_selectkbest__k           ...
# param_ridge__alpha             ...
# params                         ...
# split0_test_score              ...
# split1_test_score              ...
# split2_test_score              ...
# mean_test_score                ...
# std_test_score                 ...
# rank_test_score                ...
#
#                                                                               26  \
# mean_fit_time                                                           0.505347
# std_fit_time                                                            0.009277
# mean_score_time                                                         0.137056
# std_score_time                                                          0.023503
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                          19
# param_ridge__alpha                                                           0.1
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                   -19923.55879
# split1_test_score                                                  -23402.311956
# split2_test_score                                                  -18642.223235
# mean_test_score                                                    -20656.031327
# std_test_score                                                       2011.135363
# rank_test_score                                                               41
#
#                                                                               27  \
# mean_fit_time                                                           0.500445
# std_fit_time                                                            0.003921
# mean_score_time                                                         0.138569
# std_score_time                                                          0.011481
# param_simpleimputer__strategy                                               mean
# param_selectkbest__k                                                          18
# param_ridge__alpha                                                             1
# params                         {'simpleimputer__strategy': 'mean', 'selectkbe...
# split0_test_score                                                  -20438.876534
# split1_test_score                                                  -23380.868312
# split2_test_score                                                  -18439.495625
# mean_test_score                                                    -20753.080157
# std_test_score                                                       2029.504693
# rank_test_score                                                               42
#
#                                                                               22  \
# mean_fit_time                                                           0.739436
# std_fit_time                                                            0.160143
# mean_score_time                                                         0.171171
# std_score_time                                                          0.034088
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                          16
# param_ridge__alpha                                                             1
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                  -21291.840816
# split1_test_score                                                  -23850.734157
# split2_test_score                                                  -19173.842644
# mean_test_score                                                    -21438.805872
# std_test_score                                                        1912.15892
# rank_test_score                                                               43
#
#                                                                               41  \
# mean_fit_time                                                           0.529618
# std_fit_time                                                             0.01183
# mean_score_time                                                         0.129948
# std_score_time                                                           0.00147
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                          12
# param_ridge__alpha                                                            10
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                  -21317.574854
# split1_test_score                                                  -24624.816651
# split2_test_score                                                  -18652.576168
# mean_test_score                                                    -21531.655891
# std_test_score                                                       2442.851764
# rank_test_score                                                               44
#
#                                                                               16  \
# mean_fit_time                                                           0.512925
# std_fit_time                                                            0.003383
# mean_score_time                                                         0.122821
# std_score_time                                                          0.002246
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                          12
# param_ridge__alpha                                                           0.1
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                  -21284.603378
# split1_test_score                                                  -24717.664245
# split2_test_score                                                  -18823.482206
# mean_test_score                                                    -21608.583276
# std_test_score                                                       2417.170206
# rank_test_score                                                               45
#
#                                                                               48  \
# mean_fit_time                                                           0.526889
# std_fit_time                                                            0.022037
# mean_score_time                                                         0.127121
# std_score_time                                                          0.002343
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                          13
# param_ridge__alpha                                                           0.1
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                  -21314.966018
# split1_test_score                                                  -24771.901068
# split2_test_score                                                   -18861.32681
# mean_test_score                                                    -21649.397965
# std_test_score                                                       2424.541958
# rank_test_score                                                               46
#
#                                                                               6   \
# mean_fit_time                                                            0.51373
# std_fit_time                                                            0.019454
# mean_score_time                                                         0.142175
# std_score_time                                                          0.011363
# param_simpleimputer__strategy                                               mean
# param_selectkbest__k                                                          10
# param_ridge__alpha                                                            10
# params                         {'simpleimputer__strategy': 'mean', 'selectkbe...
# split0_test_score                                                    -21811.8445
# split1_test_score                                                  -24943.557307
# split2_test_score                                                  -19140.377914
# mean_test_score                                                    -21965.259907
# std_test_score                                                         2371.6204
# rank_test_score                                                               47
#
#                                                                               34  \
# mean_fit_time                                                           0.580638
# std_fit_time                                                             0.02844
# mean_score_time                                                          0.13291
# std_score_time                                                          0.002241
# param_simpleimputer__strategy                                               mean
# param_selectkbest__k                                                           3
# param_ridge__alpha                                                            10
# params                         {'simpleimputer__strategy': 'mean', 'selectkbe...
# split0_test_score                                                  -25340.985967
# split1_test_score                                                  -29983.237782
# split2_test_score                                                  -24222.127844
# mean_test_score                                                    -26515.450531
# std_test_score                                                       2494.276407
# rank_test_score                                                               48
#
#                                                                               44  \
# mean_fit_time                                                           0.853155
# std_fit_time                                                             0.04549
# mean_score_time                                                         0.209961
# std_score_time                                                          0.030796
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                           3
# param_ridge__alpha                                                           0.1
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                  -25366.355087
# split1_test_score                                                    -30004.8107
# split2_test_score                                                  -24831.233728
# mean_test_score                                                    -26734.133172
# std_test_score                                                       2323.013465
# rank_test_score                                                               49
#
#                                                                               15
# mean_fit_time                                                           0.544521
# std_fit_time                                                             0.00527
# mean_score_time                                                          0.13337
# std_score_time                                                          0.003572
# param_simpleimputer__strategy                                             median
# param_selectkbest__k                                                           1
# param_ridge__alpha                                                             1
# params                         {'simpleimputer__strategy': 'median', 'selectk...
# split0_test_score                                                  -30366.569217
# split1_test_score                                                   -34261.52636
# split2_test_score                                                  -28193.380997
# mean_test_score                                                    -30940.492191
# std_test_score                                                       2510.330353
# rank_test_score                                                               50
#
# [14 rows x 50 columns]

# %% [markdown]
# ### 랜덤포레스트에 적용해 보겠습니다.

# %% [markdown]
# 이번에는 `scipy.stats` 사용해 파라미터 선택을 위한 다양한 분포모듈을 활용해 봅시다

# %%
from scipy.stats import randint, uniform

pipe = make_pipeline(
    TargetEncoder(), 
    SimpleImputer(), 
    RandomForestRegressor(random_state=2)
)

dists = {
    'targetencoder__smoothing': [2.,20.,50.,60.,100.,500.,1000.], # int로 넣으면 error(bug)
    'targetencoder__min_samples_leaf': randint(1, 10),     
    'simpleimputer__strategy': ['mean', 'median'], 
    'randomforestregressor__n_estimators': randint(50, 500), 
    'randomforestregressor__max_depth': [5, 10, 15, 20, None], 
    'randomforestregressor__max_features': uniform(0, 1) # max_features
}

clf = RandomizedSearchCV(
    pipe, 
    param_distributions=dists, 
    n_iter=50, 
    cv=3, 
    scoring='neg_mean_absolute_error',  
    verbose=1,
    n_jobs=-1
)

clf.fit(X_train, y_train);
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits

# %%
print('최적 하이퍼파라미터: ', clf.best_params_)
print('MAE: ', -clf.best_score_)
# Out:
# 최적 하이퍼파라미터:  {'randomforestregressor__max_depth': 20, 'randomforestregressor__max_features': 0.4119342575386862, 'randomforestregressor__n_estimators': 167, 'simpleimputer__strategy': 'mean', 'targetencoder__min_samples_leaf': 6, 'targetencoder__smoothing': 2.0}
# MAE:  15751.851391374817

# %% [markdown]
# #### 각 하이퍼파라미터 조합으로 만들어진 모델들을 순위별로 나열해 봅니다.

# %%
pd.DataFrame(clf.cv_results_).sort_values(by='rank_test_score').T
# Out:
#                                                                                           9   \
# mean_fit_time                                                                       1.606153
# std_fit_time                                                                        0.010584
# mean_score_time                                                                     0.101072
# std_score_time                                                                      0.005885
# param_randomforestregressor__max_depth                                                    20
# param_randomforestregressor__max_features                                           0.411934
# param_randomforestregressor__n_estimators                                                167
# param_simpleimputer__strategy                                                           mean
# param_targetencoder__min_samples_leaf                                                      6
# param_targetencoder__smoothing                                                           2.0
# params                                     {'randomforestregressor__max_depth': 20, 'rand...
# split0_test_score                                                              -14875.259474
# split1_test_score                                                               -17923.09299
# split2_test_score                                                               -14457.20171
# mean_test_score                                                                -15751.851391
# std_test_score                                                                    1544.75686
# rank_test_score                                                                            1
#
#                                                                                           4   \
# mean_fit_time                                                                       3.581352
# std_fit_time                                                                        0.495957
# mean_score_time                                                                     0.145655
# std_score_time                                                                      0.009659
# param_randomforestregressor__max_depth                                                    15
# param_randomforestregressor__max_features                                           0.311013
# param_randomforestregressor__n_estimators                                                460
# param_simpleimputer__strategy                                                           mean
# param_targetencoder__min_samples_leaf                                                      4
# param_targetencoder__smoothing                                                         100.0
# params                                     {'randomforestregressor__max_depth': 15, 'rand...
# split0_test_score                                                              -14983.213821
# split1_test_score                                                              -18097.046692
# split2_test_score                                                              -14383.534795
# mean_test_score                                                                -15821.265102
# std_test_score                                                                   1627.736694
# rank_test_score                                                                            2
#
#                                                                                           1   \
# mean_fit_time                                                                        2.86291
# std_fit_time                                                                        0.254232
# mean_score_time                                                                     0.191358
# std_score_time                                                                      0.042196
# param_randomforestregressor__max_depth                                                  None
# param_randomforestregressor__max_features                                           0.172227
# param_randomforestregressor__n_estimators                                                464
# param_simpleimputer__strategy                                                         median
# param_targetencoder__min_samples_leaf                                                      9
# param_targetencoder__smoothing                                                          60.0
# params                                     {'randomforestregressor__max_depth': None, 'ra...
# split0_test_score                                                              -15195.632739
# split1_test_score                                                              -17972.139553
# split2_test_score                                                              -14320.258822
# mean_test_score                                                                -15829.343705
# std_test_score                                                                   1556.759542
# rank_test_score                                                                            3
#
#                                                                                           5   \
# mean_fit_time                                                                       1.885106
# std_fit_time                                                                        0.029242
# mean_score_time                                                                     0.124386
# std_score_time                                                                      0.000811
# param_randomforestregressor__max_depth                                                  None
# param_randomforestregressor__max_features                                           0.173726
# param_randomforestregressor__n_estimators                                                360
# param_simpleimputer__strategy                                                         median
# param_targetencoder__min_samples_leaf                                                      3
# param_targetencoder__smoothing                                                         500.0
# params                                     {'randomforestregressor__max_depth': None, 'ra...
# split0_test_score                                                              -15294.133838
# split1_test_score                                                              -17790.139268
# split2_test_score                                                              -14447.332162
# mean_test_score                                                                -15843.868423
# std_test_score                                                                   1418.977548
# rank_test_score                                                                            4
#
#                                                                                           44  \
# mean_fit_time                                                                       3.490795
# std_fit_time                                                                        0.462257
# mean_score_time                                                                     0.152813
# std_score_time                                                                      0.012952
# param_randomforestregressor__max_depth                                                  None
# param_randomforestregressor__max_features                                           0.383752
# param_randomforestregressor__n_estimators                                                425
# param_simpleimputer__strategy                                                         median
# param_targetencoder__min_samples_leaf                                                      7
# param_targetencoder__smoothing                                                          20.0
# params                                     {'randomforestregressor__max_depth': None, 'ra...
# split0_test_score                                                              -15070.793155
# split1_test_score                                                              -18123.369649
# split2_test_score                                                              -14395.002442
# mean_test_score                                                                -15863.055082
# std_test_score                                                                   1621.920616
# rank_test_score                                                                            5
#
#                                                                                           32  \
# mean_fit_time                                                                       1.903948
# std_fit_time                                                                        0.023314
# mean_score_time                                                                     0.135744
# std_score_time                                                                      0.007609
# param_randomforestregressor__max_depth                                                    15
# param_randomforestregressor__max_features                                           0.127474
# param_randomforestregressor__n_estimators                                                434
# param_simpleimputer__strategy                                                         median
# param_targetencoder__min_samples_leaf                                                      9
# param_targetencoder__smoothing                                                          60.0
# params                                     {'randomforestregressor__max_depth': 15, 'rand...
# split0_test_score                                                              -15326.397309
# split1_test_score                                                              -17982.273211
# split2_test_score                                                              -14362.718153
# mean_test_score                                                                -15890.462891
# std_test_score                                                                   1530.560287
# rank_test_score                                                                            6
#
#                                                                                           29  \
# mean_fit_time                                                                       3.464825
# std_fit_time                                                                        0.304544
# mean_score_time                                                                     0.150777
# std_score_time                                                                      0.026466
# param_randomforestregressor__max_depth                                                    15
# param_randomforestregressor__max_features                                           0.422694
# param_randomforestregressor__n_estimators                                                417
# param_simpleimputer__strategy                                                         median
# param_targetencoder__min_samples_leaf                                                      9
# param_targetencoder__smoothing                                                          60.0
# params                                     {'randomforestregressor__max_depth': 15, 'rand...
# split0_test_score                                                              -15099.415564
# split1_test_score                                                              -18176.956552
# split2_test_score                                                              -14529.753035
# mean_test_score                                                                 -15935.37505
# std_test_score                                                                   1602.008026
# rank_test_score                                                                            7
#
#                                                                                           46  \
# mean_fit_time                                                                       1.686624
# std_fit_time                                                                        0.459642
# mean_score_time                                                                     0.134768
# std_score_time                                                                      0.044702
# param_randomforestregressor__max_depth                                                  None
# param_randomforestregressor__max_features                                           0.254524
# param_randomforestregressor__n_estimators                                                181
# param_simpleimputer__strategy                                                         median
# param_targetencoder__min_samples_leaf                                                      7
# param_targetencoder__smoothing                                                          50.0
# params                                     {'randomforestregressor__max_depth': None, 'ra...
# split0_test_score                                                              -15181.181958
# split1_test_score                                                              -18221.884955
# split2_test_score                                                               -14475.49954
# mean_test_score                                                                -15959.522151
# std_test_score                                                                   1625.466294
# rank_test_score                                                                            8
#
#                                                                                           28  \
# mean_fit_time                                                                       1.181556
# std_fit_time                                                                        0.006801
# mean_score_time                                                                     0.104882
# std_score_time                                                                      0.006564
# param_randomforestregressor__max_depth                                                    20
# param_randomforestregressor__max_features                                           0.154759
# param_randomforestregressor__n_estimators                                                188
# param_simpleimputer__strategy                                                           mean
# param_targetencoder__min_samples_leaf                                                      3
# param_targetencoder__smoothing                                                          20.0
# params                                     {'randomforestregressor__max_depth': 20, 'rand...
# split0_test_score                                                              -15360.211419
# split1_test_score                                                              -18118.905672
# split2_test_score                                                              -14409.375848
# mean_test_score                                                                 -15962.83098
# std_test_score                                                                   1573.216584
# rank_test_score                                                                            9
#
#                                                                                           27  \
# mean_fit_time                                                                       1.319687
# std_fit_time                                                                        0.062977
# mean_score_time                                                                     0.099554
# std_score_time                                                                      0.008512
# param_randomforestregressor__max_depth                                                    20
# param_randomforestregressor__max_features                                            0.47006
# param_randomforestregressor__n_estimators                                                108
# param_simpleimputer__strategy                                                           mean
# param_targetencoder__min_samples_leaf                                                      1
# param_targetencoder__smoothing                                                         500.0
# params                                     {'randomforestregressor__max_depth': 20, 'rand...
# split0_test_score                                                              -15031.297178
# split1_test_score                                                              -18226.566132
# split2_test_score                                                              -14750.039784
# mean_test_score                                                                -16002.634365
# std_test_score                                                                    1576.74365
# rank_test_score                                                                           10
#
#                                            ...  \
# mean_fit_time                              ...
# std_fit_time                               ...
# mean_score_time                            ...
# std_score_time                             ...
# param_randomforestregressor__max_depth     ...
# param_randomforestregressor__max_features  ...
# param_randomforestregressor__n_estimators  ...
# param_simpleimputer__strategy              ...
# param_targetencoder__min_samples_leaf      ...
# param_targetencoder__smoothing             ...
# params                                     ...
# split0_test_score                          ...
# split1_test_score                          ...
# split2_test_score                          ...
# mean_test_score                            ...
# std_test_score                             ...
# rank_test_score                            ...
#
#                                                                                           11  \
# mean_fit_time                                                                       1.787481
# std_fit_time                                                                        0.466539
# mean_score_time                                                                     0.142482
# std_score_time                                                                      0.052704
# param_randomforestregressor__max_depth                                                     5
# param_randomforestregressor__max_features                                           0.169711
# param_randomforestregressor__n_estimators                                                346
# param_simpleimputer__strategy                                                         median
# param_targetencoder__min_samples_leaf                                                      1
# param_targetencoder__smoothing                                                          50.0
# params                                     {'randomforestregressor__max_depth': 5, 'rando...
# split0_test_score                                                              -17848.722233
# split1_test_score                                                              -20548.187189
# split2_test_score                                                              -16476.165354
# mean_test_score                                                                -18291.024925
# std_test_score                                                                   1691.560268
# rank_test_score                                                                           41
#
#                                                                                           10  \
# mean_fit_time                                                                       2.913848
# std_fit_time                                                                        0.025156
# mean_score_time                                                                     0.122328
# std_score_time                                                                       0.01073
# param_randomforestregressor__max_depth                                                     5
# param_randomforestregressor__max_features                                           0.796878
# param_randomforestregressor__n_estimators                                                453
# param_simpleimputer__strategy                                                         median
# param_targetencoder__min_samples_leaf                                                      6
# param_targetencoder__smoothing                                                           2.0
# params                                     {'randomforestregressor__max_depth': 5, 'rando...
# split0_test_score                                                              -17874.395918
# split1_test_score                                                              -21371.679787
# split2_test_score                                                               -16517.30496
# mean_test_score                                                                -18587.793555
# std_test_score                                                                   2044.984251
# rank_test_score                                                                           42
#
#                                                                                           7   \
# mean_fit_time                                                                       2.726918
# std_fit_time                                                                        0.530921
# mean_score_time                                                                     0.117444
# std_score_time                                                                      0.012733
# param_randomforestregressor__max_depth                                                     5
# param_randomforestregressor__max_features                                           0.853403
# param_randomforestregressor__n_estimators                                                342
# param_simpleimputer__strategy                                                           mean
# param_targetencoder__min_samples_leaf                                                      1
# param_targetencoder__smoothing                                                         500.0
# params                                     {'randomforestregressor__max_depth': 5, 'rando...
# split0_test_score                                                              -17917.859983
# split1_test_score                                                              -21320.982805
# split2_test_score                                                              -16802.466733
# mean_test_score                                                                -18680.436507
# std_test_score                                                                   1921.872193
# rank_test_score                                                                           43
#
#                                                                                           22  \
# mean_fit_time                                                                       1.422923
# std_fit_time                                                                        0.023646
# mean_score_time                                                                     0.094726
# std_score_time                                                                      0.008703
# param_randomforestregressor__max_depth                                                     5
# param_randomforestregressor__max_features                                           0.914651
# param_randomforestregressor__n_estimators                                                164
# param_simpleimputer__strategy                                                           mean
# param_targetencoder__min_samples_leaf                                                      1
# param_targetencoder__smoothing                                                        1000.0
# params                                     {'randomforestregressor__max_depth': 5, 'rando...
# split0_test_score                                                              -18030.749477
# split1_test_score                                                              -21519.814117
# split2_test_score                                                               -16966.55748
# mean_test_score                                                                -18839.040358
# std_test_score                                                                   1944.742847
# rank_test_score                                                                           44
#
#                                                                                           0   \
# mean_fit_time                                                                       2.677451
# std_fit_time                                                                        0.139618
# mean_score_time                                                                     0.116076
# std_score_time                                                                       0.00755
# param_randomforestregressor__max_depth                                                     5
# param_randomforestregressor__max_features                                            0.94622
# param_randomforestregressor__n_estimators                                                333
# param_simpleimputer__strategy                                                           mean
# param_targetencoder__min_samples_leaf                                                      2
# param_targetencoder__smoothing                                                          20.0
# params                                     {'randomforestregressor__max_depth': 5, 'rando...
# split0_test_score                                                              -18345.741826
# split1_test_score                                                              -21661.123675
# split2_test_score                                                              -16976.418142
# mean_test_score                                                                -18994.427881
# std_test_score                                                                    1966.75904
# rank_test_score                                                                           45
#
#                                                                                           36  \
# mean_fit_time                                                                       3.099908
# std_fit_time                                                                        0.427578
# mean_score_time                                                                     0.103535
# std_score_time                                                                       0.00136
# param_randomforestregressor__max_depth                                                     5
# param_randomforestregressor__max_features                                           0.949897
# param_randomforestregressor__n_estimators                                                357
# param_simpleimputer__strategy                                                           mean
# param_targetencoder__min_samples_leaf                                                      1
# param_targetencoder__smoothing                                                           2.0
# params                                     {'randomforestregressor__max_depth': 5, 'rando...
# split0_test_score                                                              -18400.279785
# split1_test_score                                                              -21713.020229
# split2_test_score                                                              -16896.958715
# mean_test_score                                                                -19003.419576
# std_test_score                                                                   2011.872317
# rank_test_score                                                                           46
#
#                                                                                           14  \
# mean_fit_time                                                                       0.858234
# std_fit_time                                                                        0.018961
# mean_score_time                                                                     0.114911
# std_score_time                                                                      0.005434
# param_randomforestregressor__max_depth                                                    20
# param_randomforestregressor__max_features                                           0.019422
# param_randomforestregressor__n_estimators                                                178
# param_simpleimputer__strategy                                                           mean
# param_targetencoder__min_samples_leaf                                                      4
# param_targetencoder__smoothing                                                        1000.0
# params                                     {'randomforestregressor__max_depth': 20, 'rand...
# split0_test_score                                                              -19002.519114
# split1_test_score                                                              -20631.873624
# split2_test_score                                                              -17381.435145
# mean_test_score                                                                -19005.275961
# std_test_score                                                                   1326.987384
# rank_test_score                                                                           47
#
#                                                                                           30  \
# mean_fit_time                                                                       1.076257
# std_fit_time                                                                        0.398161
# mean_score_time                                                                     0.141812
# std_score_time                                                                      0.039875
# param_randomforestregressor__max_depth                                                    15
# param_randomforestregressor__max_features                                           0.016848
# param_randomforestregressor__n_estimators                                                189
# param_simpleimputer__strategy                                                           mean
# param_targetencoder__min_samples_leaf                                                      7
# param_targetencoder__smoothing                                                        1000.0
# params                                     {'randomforestregressor__max_depth': 15, 'rand...
# split0_test_score                                                              -19397.127767
# split1_test_score                                                              -21207.866163
# split2_test_score                                                              -18137.021176
# mean_test_score                                                                -19580.671702
# std_test_score                                                                   1260.367279
# rank_test_score                                                                           48
#
#                                                                                           48  \
# mean_fit_time                                                                       0.759564
# std_fit_time                                                                        0.009574
# mean_score_time                                                                     0.097598
# std_score_time                                                                      0.008208
# param_randomforestregressor__max_depth                                                    15
# param_randomforestregressor__max_features                                           0.003217
# param_randomforestregressor__n_estimators                                                128
# param_simpleimputer__strategy                                                         median
# param_targetencoder__min_samples_leaf                                                      7
# param_targetencoder__smoothing                                                           2.0
# params                                     {'randomforestregressor__max_depth': 15, 'rand...
# split0_test_score                                                              -19354.788056
# split1_test_score                                                              -21484.809544
# split2_test_score                                                              -17933.920623
# mean_test_score                                                                -19591.172741
# std_test_score                                                                   1459.248967
# rank_test_score                                                                           49
#
#                                                                                           38
# mean_fit_time                                                                       0.674124
# std_fit_time                                                                        0.028841
# mean_score_time                                                                     0.084823
# std_score_time                                                                       0.00461
# param_randomforestregressor__max_depth                                                     5
# param_randomforestregressor__max_features                                           0.088111
# param_randomforestregressor__n_estimators                                                129
# param_simpleimputer__strategy                                                           mean
# param_targetencoder__min_samples_leaf                                                      2
# param_targetencoder__smoothing                                                          20.0
# params                                     {'randomforestregressor__max_depth': 5, 'rando...
# split0_test_score                                                              -19684.771883
# split1_test_score                                                              -21580.672821
# split2_test_score                                                              -17799.126037
# mean_test_score                                                                -19688.190247
# std_test_score                                                                   1543.811902
# rank_test_score                                                                           50
#
# [17 rows x 50 columns]

# %% [markdown]
# #### 이제 테스트 데이터에 대한 예측 결과를 살펴 봅시다.

# %%
# 만들어진 모델에서 가장 성능이 좋은 모델을 불러옵니다.
pipe = clf.best_estimator_

# %%
from sklearn.metrics import mean_absolute_error

y_pred = pipe.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f'테스트세트 MAE: ${mae:,.0f}')
# Out:
# 테스트세트 MAE: $16,427

# %%
features
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'All_Flr_SF', 'All_Liv_SF'],
#       dtype='object')

# %% [markdown]
# [`RandomizdSearchCV` documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html) 에서`best_estimator_` attribute 를 살펴 봅시다:
#
# > **best_estimator_** : ***estimator***
# > Estimator that was chosen by the search, i.e. estimator which gave highest score (or smallest loss if specified) on the left out data. Not available if `refit=False`. ... See `refit` parameter for more information ...
#
# `refit` parameter 도 살펴 봅시다.:
#
# > **refit** : ***boolean, string, or callable, default=True***
# > Refit an estimator using the best found parameters on the whole dataset.
#
# best_estimator_ 는 CV가 끝난 후 찾은 best parameter를 사용해 모든 학습데이터(all the training data)를 가지고 다시 학습(refit)한 상태입니다:
#
# <img src="https://scikit-learn.org/stable/_images/grid_search_workflow.png" width="50%">
#
# ##### 만약 여러분이 hold-out 교차검증(훈련/검증/테스트 세트로 한 번만 나누어 실험)을 수행한 경우에는, (훈련 + 검증) 데이터셋에서 최적화된 하이퍼파라미터로 최종 모델을 재학습(refit) 해야 합니다.

# %% [markdown]
# ### 선형회귀, 랜덤포레스트 모델들의 튜닝 추천 하이퍼파라미터 입니다
#
# #### Random Forest
# - class_weight (불균형(imbalanced) 클래스인 경우)
# - max_depth (너무 깊어지면 과적합)
# - n_estimators (적을경우 과소적합, 높을경우 긴 학습시간)
# - min_samples_leaf (과적합일경우 높임)
# - max_features (줄일 수록 다양한 트리생성)
#
# #### Logistic Regression
# - C (Inverse of regularization strength)
# - class_weight (불균형 클래스인 경우)
# - penalty
#
# #### Ridge / Lasso Regression
# - alpha

# %% [markdown]
# ## 참고자료
# - [Raschka, Part III - Cross-validation and hyperparameter tuning](https://sebastianraschka.com/blog/2016/model-evaluation-selection-part3.html)
# - [3.1. Cross-validation: evaluating estimator performance](https://scikit-learn.org/stable/modules/cross_validation.html)
# - [3.2. Tuning the hyper-parameters of an estimator](https://scikit-learn.org/stable/modules/grid_search.html)
# - [Scikit-Learn User Guide, 3.2 Tuning the hyper-parameters of an estimator](https://scikit-learn.org/stable/modules/grid_search.html)
# - [A Comparison of Grid Search and Randomized Search Using Scikit Learn](https://blog.usejournal.com/a-comparison-of-grid-search-and-randomized-search-using-scikit-learn-29823179bc85)

# %% [markdown]
# # Exercise
#
# # 모델선택(Model Selection)
#
# ### 1) 캐글 대회를 이어서 진행합니다. RandomizedSearchCV 를 사용하여 하이퍼파라미터 튜닝을 진행합니다.
#
# - [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)를 사용하세요.
# - 분류문제에서 맞는 [scoring parameter](https://scikit-learn.org/stable/modules/model_evaluation.html#common-cases-predefined-values) metric을 사용하세요.
# - [OrdinalEncoder](https://contrib.scikit-learn.org/categorical-encoding/ordinal.html) 사용을 권합니다.
# - RandomizedSearchCV 를 사용해서 하이퍼파라미터 튜닝을 진행하고 최고 성능을 보이는 모델로 예측을 진행한 후 캐글에 제출합니다.
# - **캐글 Leaderboard에서 개선된 본인 Score를 과제 제출폼에 제출하세요.**

# %%
#!pip install category_encoders

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from category_encoders import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from category_encoders import OrdinalEncoder
from sklearn.impute import KNNImputer
from sklearn.metrics import accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

target = 'vacc_h1n1_f'
# target = 'vacc_seas_f'
train = pd.merge(pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/vacc_flu/train.csv'), 
                 pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/vacc_flu/train_labels.csv')[target], left_index=True, right_index=True)
test = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/vacc_flu/test.csv')
sample_submission = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/vacc_flu/submission.csv')


train, val = train_test_split(train, train_size=0.80, test_size=0.20, 
                              stratify=train[target], random_state=2)


def engineer(df):
    """특성을 엔지니어링 하는 함수입니다."""
    
    # 높은 카디널리티를 가지는 특성을 제거합니다.
    #selected_cols = df.select_dtypes(include=['number', 'object'])
    #labels = selected_cols.nunique() # 특성별 카디널리티 리스트
    #selected_features = labels[labels <= 60].index.tolist() # 카디널리티가 30보다 작은 특성만 선택합니다.
    #df = df[selected_features]

    
    low = ['MISSISSIPPI', 'GEORGIA', 'MISSOURI', 'LOUISIANA', 'IDAHO', 'FLORIDA', 'ALABAMA']
    middle = ['OKLAHOMA', 'TEXAS', 'ALABAMA', 'MONTANA', 'NEW YORK','MICHIGAN', 'SOUTH CAROLINA', 'NEW JERSEY', 'OHIO', 'PENNSYLVANIA', 'TENNESSEE',
            'NEVADA', 'DELAWARE', 'CONNECTICUT', 'ILLINOIS', 'DISTRICTOF COLUMBIA', 'NEW MEXICO', 'NORTH CAROLINA', 'WEST VIRGINIA', 'OREGON', 'ALASKA', 'WISCONSIN',
            'CALIFORNIA', 'COLORADO','ARIZONA']
    high = ['INDIANA', 'MARYLAND', 'WYOMING', 'UTAH', 'ARKANSAS', 'KANSAS', 'WASHINGTON', 'NORTH DAKOTA', 'NEBRASKA', 'MINNESOTA', 'IOWA', 'VIRGINIA',
            'VERMONT', 'NEW HAMPSHIRE', 'HAWAII']
    extreme = ['MAINE', 'SOUTH DAKOTA', 'MASSACHUSETTS', 'RHODE ISLAND']

    df['danger_state_level'] = 0

    num = len(df)
    for i in range(num):
      if df['state'].iloc[i] in low:
        df['danger_state_level'].iloc[i] = 'low'

      elif df['state'].iloc[i] in middle:
        df['danger_state_level'].iloc[i] = 'middle'
      
      elif df['state'].iloc[i] in high:
        df['danger_state_level'].iloc[i] = 'high'

      else:
        df['danger_state_level'].iloc[i] = 'extreme'
    
    df.drop(['state'], axis = 1, inplace=True)

    

    # 새로운 특성을 생성합니다.
    behaviorals = [col for col in df.columns if 'behavioral' in col] 
    df['behaviorals'] = df[behaviorals].sum(axis=1)
    
    
    dels = [col for col in df.columns if ('employment' in col or 'seas' in col)]
    df.drop(columns=dels, inplace=True)
        
    return df


train = engineer(train)
val = engineer(val)
test = engineer(test)


features = train.drop(columns=[target]).columns

# Diving training, validation, and testing data into X and y
X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]
X_test = test[features]
# Out:
# <ipython-input-31-184ded589637>:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['danger_state_level'].iloc[i] = 'middle'
# <ipython-input-31-184ded589637>:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['danger_state_level'].iloc[i] = 'middle'
# <ipython-input-31-184ded589637>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['danger_state_level'].iloc[i] = 'high'

# %%
from sklearn.model_selection import validation_curve
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

# %%
pipe = make_pipeline(
    OrdinalEncoder(), 
    SimpleImputer(), 
    RandomForestClassifier(random_state=42)
)

params = {
    'simpleimputer__strategy': ['mean', 'median'],
    'randomforestclassifier__n_estimators': randint(50, 500), 
    'randomforestclassifier__max_depth': [5, 10, 15, 20, None], 
    'randomforestclassifier__max_features': uniform(0, 1)
}

clf = RandomizedSearchCV(
    pipe, 
    param_distributions=params, 
    n_iter=50, 
    cv=3, 
    scoring='accuracy',  
    verbose=1,
    n_jobs=-1
)

clf.fit(X_train, y_train);
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# /usr/local/lib/python3.9/dist-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(

# %%
print('최적 하이퍼파라미터: ', clf.best_params_)
print('accuracy: ', clf.best_score_)
# Out:
# 최적 하이퍼파라미터:  {'randomforestclassifier__max_depth': 10, 'randomforestclassifier__max_features': 0.469279465286929, 'randomforestclassifier__n_estimators': 348, 'simpleimputer__strategy': 'mean'}
# accuracy:  0.8270023426148326

# %%
pipe = clf.best_estimator_

pipe.fit(X_train, y_train)
print('검증 정확도', pipe.score(X_val, y_val))

predict = pipe.predict(X_val)
f1=f1_score(y_val, predict)

print("F1 score: {}" .format(f1))
# Out:
# 검증 정확도 0.8320483928359625
# F1 score: 0.5690809494826536

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
y_pred = clf.predict(X_val)
y_pred_proba = clf.predict_proba(X_val)[:, 1]

fpr, tpr, thresholds = roc_curve(y_val, y_pred_proba)

auc_score = roc_auc_score(y_val, y_pred_proba)

optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]

print('idx:', optimal_idx, ', threshold:', optimal_threshold)
# Out:
# idx: 1178 , threshold: 0.25935910684885677

# %%
y_pred_proba = pipe.predict_proba(X_test)[:,1]
threshold_test = 0.253
y_pred_test =  y_pred_proba > threshold_test

# %%
y_pred_test = [ 1 if i == True else 0 for i in y_pred_test]
y_pred_test = pd.Series(y_pred_test)

# %%
submission = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/vacc_flu/submission.csv')

submission['vacc_h1n1_f'] = y_pred_test
submission.to_csv('submission.csv', index = False)
submission=pd.read_csv('submission.csv')
submission
# Out:
#           Id  vacc_h1n1_f
# 0          0            0
# 1          1            0
# 2          2            0
# 3          3            0
# 4          4            0
# ...      ...          ...
# 28099  28099            0
# 28100  28100            0
# 28101  28101            0
# 28102  28102            1
# 28103  28103            1
#
# [28104 rows x 2 columns]

# %%
from google.colab import files

files.download('submission.csv')

# %% [markdown]
# ### 2) [`GridSearchCV`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) 를 사용하여 하이퍼파라미터 튜닝을 진행합니다.
# - 모델 성능을 높이기 위해 가능한 시도를 다 해보세요.
# - 모델 성능에 가장 큰 영향을 준 하이퍼파라미터에 대해서 분석하고 설명해 보세요.

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV

# %%
enc = OrdinalEncoder()
imp = SimpleImputer()
X_train_encoded = enc.fit_transform(X_train)
X_train_imputed = imp.fit_transform(X_train_encoded)
X_val_encoded = enc.transform(X_val)
X_val_imputed = imp.transform(X_val_encoded)

rf_clf = RandomForestClassifier(random_state=42, n_jobs=-1)

params = {
    'class_weight' : [None, 'balanced'],
    'max_depth' : [None, 8, 12, 16],
    'n_estimators' : [100],
    'min_samples_leaf' : [4, 6, 8, 10],
    'max_features' : ['auto', 'sqrt', 'log2']
}


clf2 = GridSearchCV(
    rf_clf,
    param_grid=params,
    cv=5,
    n_jobs=-1
    )

clf2.fit(X_train_imputed, y_train)

print('최적 하이퍼파라미터: ', clf2.best_params_)
print('accuracy: ', clf2.best_score_)

pipe = clf2.best_estimator_

pipe.fit(X_val_imputed, y_val)
print('검증 정확도', pipe.score(X_val_imputed, y_val))

predict = pipe.predict(X_val_imputed)
f1=f1_score(y_val, predict)

print("F1 score: {}" .format(f1))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# 최적 하이퍼파라미터:  {'class_weight': None, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 6, 'n_estimators': 100}
# accuracy:  0.8241260078420201
# /usr/local/lib/python3.9/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# 검증 정확도 0.866208041750682
# F1 score: 0.6520666255397903

# %%
y_pred2 = clf2.predict(X_val_imputed)
y_pred_proba2 = clf2.predict_proba(X_val_imputed)[:, 1]

fpr2, tpr2, thresholds2 = roc_curve(y_val, y_pred_proba2)

# %%
auc_score2 = roc_auc_score(y_val, y_pred_proba2)
auc_score2
# Out:
# 0.9400537505491853

# %%
optimal_idx2 = np.argmax(tpr2 - fpr2)
optimal_threshold2 = thresholds2[optimal_idx2]

print('idx:', optimal_idx2, ', threshold:', optimal_threshold2)
# Out:
# idx: 1141 , threshold: 0.2458971024245792

# %%
X_test_encoded = enc.fit_transform(X_test)
X_test_imputed = imp.fit_transform(X_train_encoded)

# %%
y_pred_proba2 = clf2.predict_proba(X_test_imputed)[:,1]
threshold_test2 = 0.246
y_pred_test2 =  y_pred_proba2 > threshold_test2

# %%
y_pred_test2 = [ 1 if i == True else 0 for i in y_pred_test]
y_pred_test2 = pd.Series(y_pred_test)

# %%
submission = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/vacc_flu/submission.csv')

submission['vacc_h1n1_f'] = y_pred_test
submission.to_csv('submission.csv', index = False)
submission=pd.read_csv('submission.csv')
submission
# Out:
#           Id  vacc_h1n1_f
# 0          0            0
# 1          1            0
# 2          2            0
# 3          3            0
# 4          4            0
# ...      ...          ...
# 28099  28099            0
# 28100  28100            0
# 28101  28101            0
# 28102  28102            1
# 28103  28103            1
#
# [28104 rows x 2 columns]

# %%
from google.colab import files

files.download('submission.csv')
